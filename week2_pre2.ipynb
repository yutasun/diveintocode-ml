# %% [markdown]
# 【問題1】乱数の作成

# %%
import numpy as np
#from numpy.random import *
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
import seaborn as sns
#import random

mu0 = [-3, 0]
sigma0 = [[1, 0.8], [0.8, 1]]
np.random.seed(0)

# 2次元正規乱数を500個生成
values0 = np.random.multivariate_normal(mu, sigma, 500)

# 散布図
sns.jointplot(values0[:,0], values0[:,1])
plt.show()
#print(values[5])

# %% [markdown]
# 【問題2】散布図による可視化

# %%
plt.scatter(values0[:,0], values0[:,1])
plt.show()

# %% [markdown]
# 【問題3】ヒストグラムによる可視化

# %%
plt.hist(values0[:,0],bins=20)
plt.xlim(-6,4)
plt.show()

plt.hist(values0[:,1],bins=20)
plt.xlim(-6,4)
plt.show()

# %% [markdown]
# 【問題4】データの追加

# %%
mu1 = [0, -3]
sigma1 = [[1, 0.8], [0.8, 1]]
np.random.seed(0)

# 2次元正規乱数を500個生成
values1 = np.random.multivariate_normal(mu1, sigma1, 500)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# 散布図
ax.scatter(values0[:,0], values0[:,1], c='blue', label='group0')
ax.scatter(values1[:,0], values1[:,1], c='orange', label='group1')
ax.legend(loc='upper right')
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   from ipykernel import kernelapp as app

# %% [markdown]
# 【問題5】データの結合

# %%
values_tolal = np.concatenate((values０, values1), axis=0)
print(values_tolal)
plt.scatter(values_tolal[:,0], values_tolal[:,1])
plt.show()
# Out:
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.40484501 -3.14372258]
#  [ 0.1584315  -2.78199606]
#  [ 1.20196495 -2.02452628]]

# %% [markdown]
# 【問題6】ラベル付け

# %%
add_array = []
for i in range(500):
    add_array.append(0)
for i in range(500):
    add_array.append(1)
add_array = np.array(add_array)
add_array = add_array.reshape(1, 1000)
print(len(add_array))
print(len(values_tolal))

values_tolalz = np.concatenate((values_tolal, add_array.T), axis=1)
print(values_tolalz)
# Out:
# 1
# 1000
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-0.40484501 -3.14372258  1.        ]
#  [ 0.1584315  -2.78199606  1.        ]
#  [ 1.20196495 -2.02452628  1.        ]]
