# %% [markdown]
# # 【問題1】データセットの取得
# <br>
# pd.read_csv()を使用して、変数に格納

# %%
import pandas as pd
df = pd.read_csv('/Users/suzukiyuuta/Downloads/train.csv')
print(df.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# # 【問題2】データセット自体の調査

# %%
trainデータに含まれるデータを元に住宅販売価格を予測するモデルを作成しTESTデータでIDごとの販売価格を計算し提出する。
予測モデルについてはさまざま手法を検証することで各モデルの特徴運用またはヴィジュアルなデータ分析の練習を行う。

# %% [markdown]
# # 【問題3】データの確認

# %% [markdown]
# 各特徴量がどういったものかを見る。（数値データか文字データなど）

# %%
df.describe
df_columns = list(df.columns)
for i in df_columns:
    print(i + str(type(df.at[0,i])))
# Out:
# Id<class 'numpy.int64'>
# MSSubClass<class 'numpy.int64'>
# MSZoning<class 'str'>
# LotFrontage<class 'numpy.float64'>
# LotArea<class 'numpy.int64'>
# Street<class 'str'>
# Alley<class 'float'>
# LotShape<class 'str'>
# LandContour<class 'str'>
# Utilities<class 'str'>
# LotConfig<class 'str'>
# LandSlope<class 'str'>
# Neighborhood<class 'str'>
# Condition1<class 'str'>
# Condition2<class 'str'>
# BldgType<class 'str'>
# HouseStyle<class 'str'>
# OverallQual<class 'numpy.int64'>
# OverallCond<class 'numpy.int64'>
# YearBuilt<class 'numpy.int64'>
# YearRemodAdd<class 'numpy.int64'>
# RoofStyle<class 'str'>
# RoofMatl<class 'str'>
# Exterior1st<class 'str'>
# Exterior2nd<class 'str'>
# MasVnrType<class 'str'>
# MasVnrArea<class 'numpy.float64'>
# ExterQual<class 'str'>
# ExterCond<class 'str'>
# Foundation<class 'str'>
# BsmtQual<class 'str'>
# BsmtCond<class 'str'>
# BsmtExposure<class 'str'>
# BsmtFinType1<class 'str'>
# BsmtFinSF1<class 'numpy.int64'>
# BsmtFinType2<class 'str'>
# BsmtFinSF2<class 'numpy.int64'>
# BsmtUnfSF<class 'numpy.int64'>
# TotalBsmtSF<class 'numpy.int64'>
# Heating<class 'str'>
# HeatingQC<class 'str'>
# CentralAir<class 'str'>
# Electrical<class 'str'>
# 1stFlrSF<class 'numpy.int64'>
# 2ndFlrSF<class 'numpy.int64'>
# LowQualFinSF<class 'numpy.int64'>
# GrLivArea<class 'numpy.int64'>
# BsmtFullBath<class 'numpy.int64'>
# BsmtHalfBath<class 'numpy.int64'>
# FullBath<class 'numpy.int64'>
# HalfBath<class 'numpy.int64'>
# BedroomAbvGr<class 'numpy.int64'>
# KitchenAbvGr<class 'numpy.int64'>
# KitchenQual<class 'str'>
# TotRmsAbvGrd<class 'numpy.int64'>
# Functional<class 'str'>
# Fireplaces<class 'numpy.int64'>
# FireplaceQu<class 'float'>
# GarageType<class 'str'>
# GarageYrBlt<class 'numpy.float64'>
# GarageFinish<class 'str'>
# GarageCars<class 'numpy.int64'>
# GarageArea<class 'numpy.int64'>
# GarageQual<class 'str'>
# GarageCond<class 'str'>
# PavedDrive<class 'str'>
# WoodDeckSF<class 'numpy.int64'>
# OpenPorchSF<class 'numpy.int64'>
# EnclosedPorch<class 'numpy.int64'>
# 3SsnPorch<class 'numpy.int64'>
# ScreenPorch<class 'numpy.int64'>
# PoolArea<class 'numpy.int64'>
# PoolQC<class 'float'>
# Fence<class 'float'>
# MiscFeature<class 'float'>
# MiscVal<class 'numpy.int64'>
# MoSold<class 'numpy.int64'>
# YrSold<class 'numpy.int64'>
# SaleType<class 'str'>
# SaleCondition<class 'str'>
# SalePrice<class 'numpy.int64'>

# %% [markdown]
# 今回の目的変数はどの列か確認する。

# %%
"SalePrice"が目的変数

# %% [markdown]
# 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# # 【問題4】欠損値への対応

# %%
pip install quilt
# Out:
# Requirement already satisfied: quilt in /opt/anaconda3/lib/python3.7/site-packages (2.9.15)
# Requirement already satisfied: tqdm>=4.11.2 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (4.36.1)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (1.17.2)
# Requirement already satisfied: packaging>=16.8 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (19.2)
# Requirement already satisfied: future>=0.16.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (0.18.2)
# Requirement already satisfied: requests>=2.12.4 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (1.12.0)
# Requirement already satisfied: xlrd>=1.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (1.2.0)
# Requirement already satisfied: pandas>=0.21.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (0.25.1)
# Requirement already satisfied: pyyaml>=3.12 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (5.1.2)
# Requirement already satisfied: pyarrow>=0.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (0.15.1)
# Requirement already satisfied: appdirs>=1.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from quilt) (1.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from packaging>=16.8->quilt) (2.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.12.4->quilt) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.12.4->quilt) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.12.4->quilt) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.12.4->quilt) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21.0->quilt) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21.0->quilt) (2019.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd #欠損値が何パーセント含まれるかを確認する。
import numpy as np
from quilt.data.ResidentMario import missingno_data
collisions = missingno_data.nyc_collision_factors()
collisions = collisions.replace("nan", np.nan)
def null_search(df_train):
    for i in df_train.columns:
        print("■■■  " + i )
        print("NULL数:" + str(df_train[i].isnull().sum() )+
                 "　　　　NULL率:" + str((df_train[i].isnull().sum()/len(df_train)).round(3)) +
                 "    データの種類数:" + str(df_train[i].value_counts().count()))
null_search(df)
# Out:
# ■■■  Id
# NULL数:0　　　　NULL率:0.0    データの種類数:1460
# ■■■  MSSubClass
# NULL数:0　　　　NULL率:0.0    データの種類数:15
# ■■■  MSZoning
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  LotFrontage
# NULL数:259　　　　NULL率:0.177    データの種類数:110
# ■■■  LotArea
# NULL数:0　　　　NULL率:0.0    データの種類数:1073
# ■■■  Street
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  Alley
# NULL数:1369　　　　NULL率:0.938    データの種類数:2
# ■■■  LotShape
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  LandContour
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  Utilities
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  LotConfig
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  LandSlope
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  Neighborhood
# NULL数:0　　　　NULL率:0.0    データの種類数:25
# ■■■  Condition1
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  Condition2
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  BldgType
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  HouseStyle
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  OverallQual
# NULL数:0　　　　NULL率:0.0    データの種類数:10
# ■■■  OverallCond
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  YearBuilt
# NULL数:0　　　　NULL率:0.0    データの種類数:112
# ■■■  YearRemodAdd
# NULL数:0　　　　NULL率:0.0    データの種類数:61
# ■■■  RoofStyle
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  RoofMatl
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  Exterior1st
# NULL数:0　　　　NULL率:0.0    データの種類数:15
# ■■■  Exterior2nd
# NULL数:0　　　　NULL率:0.0    データの種類数:16
# ■■■  MasVnrType
# NULL数:8　　　　NULL率:0.005    データの種類数:4
# ■■■  MasVnrArea
# NULL数:8　　　　NULL率:0.005    データの種類数:327
# ■■■  ExterQual
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  ExterCond
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  Foundation
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  BsmtQual
# NULL数:37　　　　NULL率:0.025    データの種類数:4
# ■■■  BsmtCond
# NULL数:37　　　　NULL率:0.025    データの種類数:4
# ■■■  BsmtExposure
# NULL数:38　　　　NULL率:0.026    データの種類数:4
# ■■■  BsmtFinType1
# NULL数:37　　　　NULL率:0.025    データの種類数:6
# ■■■  BsmtFinSF1
# NULL数:0　　　　NULL率:0.0    データの種類数:637
# ■■■  BsmtFinType2
# NULL数:38　　　　NULL率:0.026    データの種類数:6
# ■■■  BsmtFinSF2
# NULL数:0　　　　NULL率:0.0    データの種類数:144
# ■■■  BsmtUnfSF
# NULL数:0　　　　NULL率:0.0    データの種類数:780
# ■■■  TotalBsmtSF
# NULL数:0　　　　NULL率:0.0    データの種類数:721
# ■■■  Heating
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  HeatingQC
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  CentralAir
# NULL数:0　　　　NULL率:0.0    データの種類数:2
# ■■■  Electrical
# NULL数:1　　　　NULL率:0.001    データの種類数:5
# ■■■  1stFlrSF
# NULL数:0　　　　NULL率:0.0    データの種類数:753
# ■■■  2ndFlrSF
# NULL数:0　　　　NULL率:0.0    データの種類数:417
# ■■■  LowQualFinSF
# NULL数:0　　　　NULL率:0.0    データの種類数:24
# ■■■  GrLivArea
# NULL数:0　　　　NULL率:0.0    データの種類数:861
# ■■■  BsmtFullBath
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  BsmtHalfBath
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  FullBath
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  HalfBath
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  BedroomAbvGr
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  KitchenAbvGr
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  KitchenQual
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  TotRmsAbvGrd
# NULL数:0　　　　NULL率:0.0    データの種類数:12
# ■■■  Functional
# NULL数:0　　　　NULL率:0.0    データの種類数:7
# ■■■  Fireplaces
# NULL数:0　　　　NULL率:0.0    データの種類数:4
# ■■■  FireplaceQu
# NULL数:690　　　　NULL率:0.473    データの種類数:5
# ■■■  GarageType
# NULL数:81　　　　NULL率:0.055    データの種類数:6
# ■■■  GarageYrBlt
# NULL数:81　　　　NULL率:0.055    データの種類数:97
# ■■■  GarageFinish
# NULL数:81　　　　NULL率:0.055    データの種類数:3
# ■■■  GarageCars
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  GarageArea
# NULL数:0　　　　NULL率:0.0    データの種類数:441
# ■■■  GarageQual
# NULL数:81　　　　NULL率:0.055    データの種類数:5
# ■■■  GarageCond
# NULL数:81　　　　NULL率:0.055    データの種類数:5
# ■■■  PavedDrive
# NULL数:0　　　　NULL率:0.0    データの種類数:3
# ■■■  WoodDeckSF
# NULL数:0　　　　NULL率:0.0    データの種類数:274
# ■■■  OpenPorchSF
# NULL数:0　　　　NULL率:0.0    データの種類数:202
# ■■■  EnclosedPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:120
# ■■■  3SsnPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:20
# ■■■  ScreenPorch
# NULL数:0　　　　NULL率:0.0    データの種類数:76
# ■■■  PoolArea
# NULL数:0　　　　NULL率:0.0    データの種類数:8
# ■■■  PoolQC
# NULL数:1453　　　　NULL率:0.995    データの種類数:3
# ■■■  Fence
# NULL数:1179　　　　NULL率:0.808    データの種類数:4
# ■■■  MiscFeature
# NULL数:1406　　　　NULL率:0.963    データの種類数:4
# ■■■  MiscVal
# NULL数:0　　　　NULL率:0.0    データの種類数:21
# ■■■  MoSold
# NULL数:0　　　　NULL率:0.0    データの種類数:12
# ■■■  YrSold
# NULL数:0　　　　NULL率:0.0    データの種類数:5
# ■■■  SaleType
# NULL数:0　　　　NULL率:0.0    データの種類数:9
# ■■■  SaleCondition
# NULL数:0　　　　NULL率:0.0    データの種類数:6
# ■■■  SalePrice
# NULL数:0　　　　NULL率:0.0    データの種類数:663

# %% [markdown]
# 5つ以上欠損値がある特徴量（列）は削除する。

# %%
def null_red1(df_train):
    for i in df_train.columns:
        if df_train[i].isnull().sum() >= 5:
            df_train = df_train.drop(i, axis=1)
    return df_train
df = null_red1(df)
print(df)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0       AllPub    Inside       Gtl  ...             0         0           0
# 1       AllPub       FR2       Gtl  ...             0         0           0
# 2       AllPub    Inside       Gtl  ...             0         0           0
# 3       AllPub    Corner       Gtl  ...           272         0           0
# 4       AllPub       FR2       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1455    AllPub    Inside       Gtl  ...             0         0           0
# 1456    AllPub    Inside       Gtl  ...             0         0           0
# 1457    AllPub    Inside       Gtl  ...             0         0           0
# 1458    AllPub    Inside       Gtl  ...           112         0           0
# 1459    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0           0       0       2    2008        WD         Normal    208500
# 1           0       0       5    2007        WD         Normal    181500
# 2           0       0       9    2008        WD         Normal    223500
# 3           0       0       2    2006        WD        Abnorml    140000
# 4           0       0      12    2008        WD         Normal    250000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1455        0       0       8    2007        WD         Normal    175000
# 1456        0       0       2    2010        WD         Normal    210000
# 1457        0    2500       5    2010        WD         Normal    266500
# 1458        0       0       4    2010        WD         Normal    142125
# 1459        0       0       6    2008        WD         Normal    147500
#
# [1460 rows x 63 columns]

# %% [markdown]
# 欠損値があるサンプル（行）は削除する。

# %%
def null_red0(df_train1):
    for i in range(len(df_train1)):
        if df_train1.iloc[i].isnull().sum() > 0:
            df_train1 = df_train1.drop(i)
    return df_train1
df = null_red0(df)
print(df)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0       AllPub    Inside       Gtl  ...             0         0           0
# 1       AllPub       FR2       Gtl  ...             0         0           0
# 2       AllPub    Inside       Gtl  ...             0         0           0
# 3       AllPub    Corner       Gtl  ...           272         0           0
# 4       AllPub       FR2       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1455    AllPub    Inside       Gtl  ...             0         0           0
# 1456    AllPub    Inside       Gtl  ...             0         0           0
# 1457    AllPub    Inside       Gtl  ...             0         0           0
# 1458    AllPub    Inside       Gtl  ...           112         0           0
# 1459    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0           0       0       2    2008        WD         Normal    208500
# 1           0       0       5    2007        WD         Normal    181500
# 2           0       0       9    2008        WD         Normal    223500
# 3           0       0       2    2006        WD        Abnorml    140000
# 4           0       0      12    2008        WD         Normal    250000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1455        0       0       8    2007        WD         Normal    175000
# 1456        0       0       2    2010        WD         Normal    210000
# 1457        0    2500       5    2010        WD         Normal    266500
# 1458        0       0       4    2010        WD         Normal    142125
# 1459        0       0       6    2008        WD         Normal    147500
#
# [1459 rows x 63 columns]

# %% [markdown]
# # 【問題5】用語の調査

# %%
尖度:正規分布に対して裾野広がり具合を表す尺度（歪度＝０は正規分布であるための必要条件）
歪度:正規分布に対して左右の非対称性を表す尺度（尖度＝０は正規分布であるための必要条件）

# %% [markdown]
# # 【問題6】分布の確認

# %% [markdown]
# seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print(df.SalePrice.describe())

print("Skewness :", df.SalePrice.skew())
print("Kurtosis :", df.SalePrice.kurt())

# 以下サンプル
# def null_skew(df_skew):
#     for i in df_skew.columns:
#         print("Skewness :", df[i].skew())
# null_skew(df['SalePrice'])
# Out:
# count      1459.000000
# mean     180930.394791
# std       79468.964025
# min       34900.000000
# 25%      129950.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skewness : 1.8819429948035529
# Kurtosis : 6.529263049673958

# %% [markdown]
# 目的変数に対して対数変換を行う。

# %%
df_y = df.SalePrice.values
log_df_y = pd.DataFrame(np.log(df_y))

print(log_df_y)
# Out:
#               0
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1454  12.072541
# 1455  12.254863
# 1456  12.493130
# 1457  11.864462
# 1458  11.901583
#
# [1459 rows x 1 columns]

# %% [markdown]
# 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する

# %%
print("Skewness :", log_df_y.skew())
print("Kurtosis :", log_df_y.kurt())

# log_df_y = pd.DataFrame(log_df_y,columns = ['SalePrice_log'])
# print(log_df_y)
# Out:
# Skewness : 0    0.121318
# dtype: float64
# Kurtosis : 0    0.806928
# dtype: float64

# %% [markdown]
# 対数変換することで正規分布に近づけた

# %% [markdown]
# # 【問題7】相関係数の確認

# %% [markdown]
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。

# %%
# type(df.at[0,i]) is str

# 文字列を削除
def str_red(df_train):
    for i in df_train.columns:
        if type(df_train.at[0,i]) is str:
            df_train = df_train.drop(i, axis=1)
    return df_train
df = str_red(df)

sns.heatmap(df.corr(method='pearson'),
            vmin=0.6,
            vmax=1.0,
            center=0,
#             annot=True, # True:格子の中に値を表示
#             fmt='.1f',
#             xticklabels=df.corr(method='pearson').columns.values,
#             yticklabels=df.corr(method='pearson').columns.values
           )
plt.show()
df_final0 = df.corr(method='pearson')
print(df_final0)
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.010589 -0.033170    -0.027553     0.013167
# MSSubClass     0.010589    1.000000 -0.139766     0.032936    -0.059134
# LotArea       -0.033170   -0.139766  1.000000     0.105786    -0.005665
# OverallQual   -0.027553    0.032936  0.105786     1.000000    -0.092243
# OverallCond    0.013167   -0.059134 -0.005665    -0.092243     1.000000
# YearBuilt     -0.013945    0.027435  0.014296     0.573334    -0.375780
# YearRemodAdd  -0.023158    0.040199  0.013852     0.551605     0.074158
# BsmtFinSF1    -0.004001   -0.069501  0.214121     0.239265    -0.046595
# BsmtFinSF2    -0.005668   -0.065549  0.111158    -0.059291     0.040132
# BsmtUnfSF     -0.007508   -0.140627 -0.002641     0.308018    -0.137008
# TotalBsmtSF   -0.013815   -0.238160  0.260962     0.537523    -0.171796
# 1stFlrSF       0.011627   -0.251484  0.299533     0.475933    -0.144646
# 2ndFlrSF       0.004885    0.307713  0.051030     0.295969     0.029187
# LowQualFinSF  -0.044139    0.046524  0.004773    -0.030502     0.025454
# GrLivArea      0.008524    0.074949  0.263109     0.593021    -0.079777
# BsmtFullBath   0.003158    0.003799  0.158147     0.110700    -0.055250
# BsmtHalfBath  -0.019917   -0.002243  0.048034    -0.040291     0.117749
# FullBath       0.004758    0.131354  0.126100     0.551267    -0.193929
# HalfBath       0.005494    0.177004  0.014333     0.274328    -0.060371
# BedroomAbvGr   0.037577   -0.023502  0.119700     0.101789     0.013039
# KitchenAbvGr   0.003177    0.281833 -0.017796    -0.184040    -0.087085
# TotRmsAbvGrd   0.026948    0.040274  0.190037     0.427720    -0.057485
# Fireplaces    -0.018788   -0.045232  0.271398     0.396455    -0.024167
# GarageCars     0.016254   -0.040232  0.154893     0.600991    -0.185670
# GarageArea     0.018010   -0.098558  0.180392     0.561980    -0.151662
# WoodDeckSF    -0.029716   -0.012598  0.171701     0.239000    -0.003318
# OpenPorchSF    0.000267   -0.005838  0.084751     0.308554    -0.032847
# EnclosedPorch  0.003272   -0.011904 -0.018360    -0.114162     0.070238
# 3SsnPorch     -0.046550   -0.043786  0.020417     0.030314     0.025465
# ScreenPorch    0.001617   -0.025932  0.043147     0.064755     0.054721
# PoolArea       0.057163    0.008309  0.077669     0.065143    -0.002009
# MiscVal       -0.006155   -0.007651  0.038063    -0.031461     0.068752
# MoSold         0.021708   -0.013404  0.001179     0.070570    -0.003685
# YrSold         0.000566   -0.021461 -0.014254    -0.027277     0.044003
# SalePrice     -0.021756   -0.084230  0.263837     0.791069    -0.077924
#
#                YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Id             -0.013945     -0.023158   -0.004001   -0.005668  -0.007508
# MSSubClass      0.027435      0.040199   -0.069501   -0.065549  -0.140627
# LotArea         0.014296      0.013852    0.214121    0.111158  -0.002641
# OverallQual     0.573334      0.551605    0.239265   -0.059291   0.308018
# OverallCond    -0.375780      0.074158   -0.046595    0.040132  -0.137008
# YearBuilt       1.000000      0.592512    0.250465   -0.048903   0.149444
# YearRemodAdd    0.592512      1.000000    0.129259   -0.067575   0.181520
# BsmtFinSF1      0.250465      0.129259    1.000000   -0.050328  -0.495718
# BsmtFinSF2     -0.048903     -0.067575   -0.050328    1.000000  -0.209395
# BsmtUnfSF       0.149444      0.181520   -0.495718   -0.209395   1.000000
# TotalBsmtSF     0.393159      0.292546    0.521963    0.104593   0.415283
# 1stFlrSF        0.283056      0.241344    0.445473    0.096948   0.317827
# 2ndFlrSF        0.009784      0.139607   -0.136697   -0.099146   0.004661
# LowQualFinSF   -0.183774     -0.062356   -0.064604    0.014784   0.028134
# GrLivArea       0.199286      0.287677    0.208088   -0.009686   0.240210
# BsmtFullBath    0.188374      0.120148    0.649025    0.158557  -0.423256
# BsmtHalfBath   -0.037990     -0.012165    0.067281    0.070904  -0.095880
# FullBath        0.467960      0.438733    0.059102   -0.076306   0.289189
# HalfBath        0.241923      0.182595    0.005085   -0.031922  -0.040792
# BedroomAbvGr   -0.070813     -0.040718   -0.107281   -0.015696   0.166701
# KitchenAbvGr   -0.174715     -0.149503   -0.081175   -0.040795   0.030028
# TotRmsAbvGrd    0.095401      0.191603    0.044529   -0.035170   0.250754
# Fireplaces      0.148580      0.113360    0.259541    0.046748   0.051323
# GarageCars      0.537866      0.420573    0.224342   -0.038204   0.214284
# GarageArea      0.479460      0.372012    0.296851   -0.018295   0.183224
# WoodDeckSF      0.224946      0.205773    0.204403    0.067909  -0.005304
# OpenPorchSF     0.189359      0.226944    0.111346    0.002954   0.128835
# EnclosedPorch  -0.387177     -0.193740   -0.102581    0.036475  -0.002640
# 3SsnPorch       0.031461      0.045389    0.026382   -0.030017   0.020732
# ScreenPorch    -0.050175     -0.038558    0.061862    0.088823  -0.012657
# PoolArea        0.005006      0.005882    0.140491    0.041697  -0.035114
# MiscVal        -0.034330     -0.010226    0.003514    0.004923  -0.023863
# MoSold          0.012791      0.021860   -0.016060   -0.015309   0.034754
# YrSold         -0.013733      0.035656    0.014456    0.031734  -0.041221
# SalePrice       0.523273      0.507430    0.386436   -0.011412   0.214446
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id             ...   -0.029716     0.000267       0.003272  -0.046550
# MSSubClass     ...   -0.012598    -0.005838      -0.011904  -0.043786
# LotArea        ...    0.171701     0.084751      -0.018360   0.020417
# OverallQual    ...    0.239000     0.308554      -0.114162   0.030314
# OverallCond    ...   -0.003318    -0.032847       0.070238   0.025465
# YearBuilt      ...    0.224946     0.189359      -0.387177   0.031461
# YearRemodAdd   ...    0.205773     0.226944      -0.193740   0.045389
# BsmtFinSF1     ...    0.204403     0.111346      -0.102581   0.026382
# BsmtFinSF2     ...    0.067909     0.002954       0.036475  -0.030017
# BsmtUnfSF      ...   -0.005304     0.128835      -0.002640   0.020732
# TotalBsmtSF    ...    0.232255     0.246764      -0.095938   0.037292
# 1stFlrSF       ...    0.235582     0.211278      -0.065580   0.056042
# 2ndFlrSF       ...    0.092159     0.208418       0.062166  -0.024308
# LowQualFinSF   ...   -0.025440     0.018196       0.061055  -0.004305
# GrLivArea      ...    0.247445     0.330175       0.009057   0.020625
# BsmtFullBath   ...    0.175382     0.066972      -0.050126  -0.000172
# BsmtHalfBath   ...    0.040170    -0.025445      -0.008615   0.035095
# FullBath       ...    0.187719     0.260459      -0.114928   0.035424
# HalfBath       ...    0.108098     0.200471      -0.095068  -0.004877
# BedroomAbvGr   ...    0.046849     0.093905       0.041613  -0.024465
# KitchenAbvGr   ...   -0.090125    -0.070206       0.037263  -0.024618
# TotRmsAbvGrd   ...    0.165980     0.234382       0.004225  -0.006660
# Fireplaces     ...    0.200111     0.169027      -0.025065   0.011185
# GarageCars     ...    0.226340     0.213763      -0.151369   0.035791
# GarageArea     ...    0.224686     0.241320      -0.121871   0.035061
# WoodDeckSF     ...    1.000000     0.058693      -0.125983  -0.032767
# OpenPorchSF    ...    0.058693     1.000000      -0.093273  -0.005900
# EnclosedPorch  ...   -0.125983    -0.093273       1.000000  -0.037336
# 3SsnPorch      ...   -0.032767    -0.005900      -0.037336   1.000000
# ScreenPorch    ...   -0.074175     0.074188      -0.082937  -0.031458
# PoolArea       ...    0.073381     0.060739       0.054188  -0.007997
# MiscVal        ...   -0.009548    -0.018629       0.018340   0.000347
# MoSold         ...    0.021028     0.071037      -0.029011   0.029437
# YrSold         ...    0.022266    -0.057563      -0.009882   0.018656
# SalePrice      ...    0.324422     0.315831      -0.128627   0.044571
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# Id                0.001617  0.057163 -0.006155  0.021708  0.000566  -0.021756
# MSSubClass       -0.025932  0.008309 -0.007651 -0.013404 -0.021461  -0.084230
# LotArea           0.043147  0.077669  0.038063  0.001179 -0.014254   0.263837
# OverallQual       0.064755  0.065143 -0.031461  0.070570 -0.027277   0.791069
# OverallCond       0.054721 -0.002009  0.068752 -0.003685  0.044003  -0.077924
# YearBuilt        -0.050175  0.005006 -0.034330  0.012791 -0.013733   0.523273
# YearRemodAdd     -0.038558  0.005882 -0.010226  0.021860  0.035656   0.507430
# BsmtFinSF1        0.061862  0.140491  0.003514 -0.016060  0.014456   0.386436
# BsmtFinSF2        0.088823  0.041697  0.004923 -0.015309  0.031734  -0.011412
# BsmtUnfSF        -0.012657 -0.035114 -0.023863  0.034754 -0.041221   0.214446
# TotalBsmtSF       0.084275  0.126083 -0.018586  0.012693 -0.014835   0.613905
# 1stFlrSF          0.088598  0.131526 -0.021167  0.031032 -0.013508   0.605968
# 2ndFlrSF          0.040738  0.081531  0.016240  0.035398 -0.028768   0.319464
# LowQualFinSF      0.026778  0.062152 -0.003800 -0.022216 -0.028910  -0.025620
# GrLivArea         0.101472  0.170198 -0.002430  0.050167 -0.036505   0.708618
# BsmtFullBath      0.023002  0.067593 -0.023102 -0.025644  0.067143   0.227082
# BsmtHalfBath      0.032078  0.020014 -0.007381  0.032795 -0.046502  -0.016873
# FullBath         -0.007962  0.049652 -0.014245  0.056153 -0.019748   0.560881
# HalfBath          0.072693  0.022451  0.001365 -0.008644 -0.010391   0.284400
# BedroomAbvGr      0.044332  0.070711  0.007777  0.046603 -0.036030   0.168235
# KitchenAbvGr     -0.051655 -0.014535  0.062329  0.026521  0.031708  -0.135935
# TotRmsAbvGrd      0.059441  0.083774  0.024782  0.037011 -0.034546   0.533779
# Fireplaces        0.184416  0.095058  0.001352  0.046056 -0.024013   0.466968
# GarageCars        0.050554  0.020949 -0.043063  0.040631 -0.039148   0.640473
# GarageArea        0.051352  0.061034 -0.027422  0.027863 -0.027347   0.623423
# WoodDeckSF       -0.074175  0.073381 -0.009548  0.021028  0.022266   0.324422
# OpenPorchSF       0.074188  0.060739 -0.018629  0.071037 -0.057563   0.315831
# EnclosedPorch    -0.082937  0.054188  0.018340 -0.029011 -0.009882  -0.128627
# 3SsnPorch        -0.031458 -0.007997  0.000347  0.029437  0.018656   0.044571
# ScreenPorch       1.000000  0.051296  0.031930  0.023129  0.010720   0.111419
# PoolArea          0.051296  1.000000  0.029665 -0.033762 -0.059683   0.092397
# MiscVal           0.031930  0.029665  1.000000 -0.006524  0.004915  -0.021200
# MoSold            0.023129 -0.033762 -0.006524  1.000000 -0.145688   0.046380
# YrSold            0.010720 -0.059683  0.004915 -0.145688  1.000000  -0.028907
# SalePrice         0.111419  0.092397 -0.021200  0.046380 -0.028907   1.000000
#
# [35 rows x 35 columns]

# %% [markdown]
# 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。

# %% [markdown]
# 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。

# %% [markdown]
# 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。
